# %% [markdown]
# #Unique
# O/p of unique is always 1D array
# Element of unique array are unique

# %%
import numpy as np


ar1 = np.array([1,2,3,3,4])
print(np.unique(ar1))

ar2 = np.array([[1,2],[2,3],[4,5]])
print(np.unique(ar2))
# Out:
# [1 2 3 4]
# [1 2 3 4 5]

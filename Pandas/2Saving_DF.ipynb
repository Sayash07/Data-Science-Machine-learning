# %%
import pandas as pd


Students = {
    "name" : ["nitan", "Hari", "Shyam", "Sita"],
    "age" : [20,21,24,28],
    "gender" : ["Male","Male", "Male", "Female"]
}

df = pd.DataFrame(Students)
df.to_csv("Students.csv", index = False)
df.to_excel("Students.xlsx", index = False)
df.to_json("Students.json", index = False)

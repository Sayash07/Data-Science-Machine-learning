# %%
import pandas as pd


df = pd.DataFrame(
    {
    "Name":["Ram", "Shyam", "Hari", "Sita", "Gita"],
    "Salary":[20000, None, 30000, 40000, 50000],
    "S":[30000, 40000, 50000, 60000, 70000]
    }
)

# %%
df["Salary"] = df["Salary"].fillna(df["S"])
df
# Out:
#     Name   Salary      S
# 0    Ram  20000.0  30000
# 1  Shyam  40000.0  40000
# 2   Hari  30000.0  50000
# 3   Sita  40000.0  60000
# 4   Gita  50000.0  70000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
ages =[12, 15, 14, 10, 18, 21, 16, 13, 15, 17, 19, 25, 14, 16, 18]
sns.boxplot(ages)
# Out:
# <Axes: >

# %% [markdown]
# 5 number summary
# Q1,Q2,Q3, Lower whisker, Upper Whisker
#
# Outlier:
# Data above Q3+1.5IQR (Upper Fence) or Q1-1.5IQR (Lower Fence)
#
# Lower whisker:
# Minimum data point after removing outlier
#
# Upper whisker:
# Maximum data point after removing outlier

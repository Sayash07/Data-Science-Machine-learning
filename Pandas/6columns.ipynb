# %%
import pandas as pd

data = {
    "Name": ["Ram", "Sita", "Hari", "Gita", "Nabin", "Asha", "Rohan", "Mina"],
    "Age": [20, 21, 19, 22, 20, 21, 23, 19],
    "Gender": ["M", "F", "M", "F", "M", "F", "M", "F"],
    "Math": [85.2134, 90.67812, 70, 95, 60, 88, 75, 92],
    "Science": [80, 85, 75, 90, 65, 95, 70, 89],
    "City": ["Kathmandu", "Pokhara", "Kathmandu", "Lalitpur",
             "Bhaktapur", "Pokhara", "Kathmandu", "Lalitpur"]
}

df = pd.DataFrame(data)

# %%
# Add column
df["Total_Marks"] = df["Math"] + df["Science"]

# %%
# Get column
df("City")

# %%
#Get multiple column:
df[["City", "Math"]]

# %%
#Update column:
df["Age"] = [1,2,3,4,5,6,7,8]

# %%
#Update multiple column:
df[["Age", "Gender"]] = [
    [10,"Male"],
    [11,"Female"],
    [12,"Male"],
    [13,"Male"],
    [14,"Female"],
    [15,"Male"],
    [16,"Male"],
    [17,"Female"],
    
]

# %%
#Delete column:
#df.drop(columns = ["Age"]) # Single column
#df.drop(columns=["Age", "Total_Marks"]) # Multiple Columns(Only deletes but doesn't change orginal)
#df.drop(columns = ["Age", "Total_Marks", inplace = True]) # This will delete it from original array

# %%
#Rename the column:
df.rename(columns={"Name" : "FirstName"},inplace=True)
df
# Out:
#   FirstName  Gender      Math  Science       City
# 0       Ram    Male  85.21340       80  Kathmandu
# 1      Sita  Female  90.67812       85    Pokhara
# 2      Hari    Male  70.00000       75  Kathmandu
# 3      Gita    Male  95.00000       90   Lalitpur
# 4     Nabin  Female  60.00000       65  Bhaktapur
# 5      Asha    Male  88.00000       95    Pokhara
# 6     Rohan    Male  75.00000       70  Kathmandu
# 7      Mina  Female  92.00000       89   Lalitpur

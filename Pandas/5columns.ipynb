# %%
import pandas as pd

data = {
    "Name": ["Ram", "Sita", "Hari", "Gita", "Nabin", "Asha", "Rohan", "Mina"],
    "Age": [20, 21, 19, 22, 20, 21, 23, 19],
    "Gender": ["M", "F", "M", "F", "M", "F", "M", "F"],
    "Math": [85.2134, 90.67812, 70, 95, 60, 88, 75, 92],
    "Science": [80, 85, 75, 90, 65, 95, 70, 89],
    "City": ["Kathmandu", "Pokhara", "Kathmandu", "Lalitpur",
             "Bhaktapur", "Pokhara", "Kathmandu", "Lalitpur"]
}

df = pd.DataFrame(data)

# %%
df["Name"]
df[["Name", "Age", "Gender"]]
# Out:
#     Name  Age Gender
# 0    Ram   20      M
# 1   Sita   21      F
# 2   Hari   19      M
# 3   Gita   22      F
# 4  Nabin   20      M
# 5   Asha   21      F
# 6  Rohan   23      M
# 7   Mina   19      F

# %%
#Find Columns:
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Math', 'Science', 'City'], dtype='str')

# %%
df.columns[-1]
# Out:
# 'City'

# %% [markdown]
# Types of Variables :
#
#     Numerical Variable (Age,Salary)
#
#     Categorical Variable(Gender, Country)

# %% [markdown]
# Average(Mean, Median)
#
# Numerical
#     Mean( It is not used if data has outlier)
#     Median( It is used if data has outlier)
#
# Categorical
#     Mode( Outlier doesn't affect mode )

# %% [markdown]
# Outlier:
# A value that is unusually far away from the other values in a dataset.
# Mean cannot be used if outlier is available.

# %% [markdown]
# Median
# 10,20,30,40,50 (For odd number)
#
# median = 30
#
# 10,20,30,50,60,40 (for even number) >> We should rearrange in accending order
# >> 10,20,30,40,50,60
# Median = (30+40) / 2 => 35
#
# 50 % vanda tala ko marks chai 35 vanda tala cha

# %% [markdown]
# Quartile:
# Q1 = 25%
# Q2 = 50%
# Q3 = 75%
# >>10,20,30,40,50 (Odd data set)
# Q2 = 30
# Q1 = 15
# Q3 = 45
#
# >> 10,3,4,2,7,8 (Even data set)
# 2,3,4,7,8,10
# Q2 = 4+7/2 => 5.5
# Q1 = 2,[3,4] = 3+4/2 = 3.5
# Q3 = 7,[8,10] = 8+10/2 = 9

# %% [markdown]
# IQR(Inter Quartile Range):
# IQR = Q3 - Q1

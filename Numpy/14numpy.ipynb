# %% [markdown]
# Filter

# %%
import numpy as np


ages = np.array([10,25,45,67,78])

ages[ages >= 18]

# %%
# & , | , ~
#Filter age between 40 and 50

ages[(ages>= 40) & (ages <= 50)]

# %%
ages[(ages ==17) | (ages == 25)]

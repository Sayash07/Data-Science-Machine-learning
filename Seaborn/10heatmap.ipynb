# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "Name": [
        "Ram", "Sita", "Hari", "Gita", "John",
        "Asha", "Bikash", "Mina", "Raj", "Puja",
        "Sam", "Anita", "Kiran", "Rita", "David",
        "Nisha", "Ramesh", "Sunita", "Arjun", "Maya",
        "Suman", "Priya", "Roshan", "Sarita", "Amit",
        "Kabita", "Manoj", "Laxmi", "Binod", "Priti",
        "Sagar", "Anu", "Nabin", "Rekha", "Dipak",
        "Sabina", "Ashok", "Bina", "Rajan", "Karuna",
        "Bimal", "Sneha", "Prakash", "Smriti", "Niraj",
        "Rojina", "Suresh", "Alisha", "Bikram", "Neha"
    ],

    "Age": [
        None, 21, None, None, None, 23, 21, None, 24, None,
        None, 21, 23, None, None, 25, 21, None, None, 23,
        None, 21, 24, None, None, None, 23, 21, None, 24,
        None, None, 21, 23, None, None, 25, 21, None, 23,
        24, None, 21, None, 23, None, None, 24, 21, None
    ],

    "Attendance": [
        85, 90, 78, 92, 88, 75, 95, 82, 89, 91,
        76, None, 93, 87, 80, 72, 96, 81, 88, 90,
        85, 79, 94, 86, 77, 91, None, 89, 95, 74,
        88, 92, 80, 85, 90, 78, 97, None, 87, 91,
        79, 86, 93, 75, 89, None, 90, 82, 96, 88
    ],

    "Python": [
        78, 85, 72, 90, 88, 65, 92, 80, 76, 95,
        70, 82, 89, 75, None, 68, 94, 79, 86, 91,
        77, None, 88, 81, 73, 90, 85, 78, 92, 69,
        87, 93, 80, 76, 89, 74, 96, 82, 85, 91,
        71, 88, None, 79, 90, 86, 75, 92, None, 87
    ],

    "Database": [
        82, 88, 75, 91, 85, 70, 94, 79, None, 90,
        72, 86, 92, 78, 81, 65, 96, None, 87, 89,
        76, 80, 93, 85, 74, 91, 88, 82, 95, 71,
        89, 94, 79, None, 86, 77, 97, 81, 90, 92,
        73, 85, 88, 76, 91, None, 80, 93, 87, 89
    ],

    "Machine_Learning": [
        75, 82, 70, 88, 91, 64, 95, 78, 85, 92,
        68, 80, 87, 73, None, 67, 93, 76, 89, 90,
        72, 85, 91, 79, 71, 94, 86, 77, 92, 68,
        None, 90, 78, 81, 88, 73, 96, 80, 87, 91,
        69, 86, None, 75, 89, 82, 79, 94, 85, 88
    ]
})

df
# Out:
#        Name   Age  Attendance  Python  Database  Machine_Learning
# 0       Ram   NaN        85.0    78.0      82.0              75.0
# 1      Sita  21.0        90.0    85.0      88.0              82.0
# 2      Hari   NaN        78.0    72.0      75.0              70.0
# 3      Gita   NaN        92.0    90.0      91.0              88.0
# 4      John   NaN        88.0    88.0      85.0              91.0
# 5      Asha  23.0        75.0    65.0      70.0              64.0
# 6    Bikash  21.0        95.0    92.0      94.0              95.0
# 7      Mina   NaN        82.0    80.0      79.0              78.0
# 8       Raj  24.0        89.0    76.0       NaN              85.0
# 9      Puja   NaN        91.0    95.0      90.0              92.0
# 10      Sam   NaN        76.0    70.0      72.0              68.0
# 11    Anita  21.0         NaN    82.0      86.0              80.0
# 12    Kiran  23.0        93.0    89.0      92.0              87.0
# ...

# %%
import seaborn as sns
null_table = df.isna()
sns.heatmap(null_table)
# Out:
# <Axes: >

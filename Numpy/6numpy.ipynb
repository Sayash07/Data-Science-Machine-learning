# %% [markdown]
# #seed
# Fix the input with same random numbers every time
# number inside parenthesis is denoted that rnadom number is fixed to that number

# %%
import numpy as np

np.random.seed(1) # usually 42 is wrriten 
l1 = np.random.randint(1,11,(3,4))
print(l1)

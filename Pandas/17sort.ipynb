# %%
import pandas as pd
data = {
    "Name": ['nitan', 'ram', 'hari',"gita"],
    "Age": [28, 28, 22,34],
    "Salary": [30000, 20000, 30000,10000]
}
df=pd.DataFrame(data)

# %%
df.sort_values(by =["Age", "Name"], ascending = [True, True], inplace=True)

df

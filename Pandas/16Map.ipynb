# %%
import pandas as pd
df = pd.DataFrame({
    "Study Hours": [2, 3, 4, 5, 6, 7, 1, 8],
    "Attendance": [60, 65, 70, 75, 80, 85, 50, 90],
    "Gender": ["Male", "Female", "Male", "Female",
               "Male", "Female", "Male", "Female"],
    "Result": ["Fail", "Fail", "Pass", "Pass",
               "Pass", "Pass", "Fail", "Pass"]
})
print(df)
# Out:
#    Study Hours  Attendance  Gender Result
# 0            2          60    Male   Fail
# 1            3          65  Female   Fail
# 2            4          70    Male   Pass
# 3            5          75  Female   Pass
# 4            6          80    Male   Pass
# 5            7          85  Female   Pass
# 6            1          50    Male   Fail
# 7            8          90  Female   Pass

# %%
df["Result"]= df["Result"].map({"Fail":0,"Pass":1})
df
# Out:
#    Study Hours  Attendance  Gender  Result
# 0            2          60    Male       0
# 1            3          65  Female       0
# 2            4          70    Male       1
# 3            5          75  Female       1
# 4            6          80    Male       1
# 5            7          85  Female       1
# 6            1          50    Male       0
# 7            8          90  Female       1

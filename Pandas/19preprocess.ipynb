# %%
import pandas as pd
df = pd.DataFrame({
    "Study Hours": [2, 3, 4, 5, 6, 7, 1, 8],
    "Attendance": [60, 65, 70, 75, 80, 85, 50, 90],
    "Gender": ["Male", "Female", "Male", "Female",
               "Male", "Female", "Male", "Female"],
    "Result": ["Fail", "Fail", "Pass", "Pass",
               "Pass", "Pass", "Fail", "Pass"]
})
print(df)
# Out:
#    Study Hours  Attendance  Gender Result
# 0            2          60    Male   Fail
# 1            3          65  Female   Fail
# 2            4          70    Male   Pass
# 3            5          75  Female   Pass
# 4            6          80    Male   Pass
# 5            7          85  Female   Pass
# 6            1          50    Male   Fail
# 7            8          90  Female   Pass

# %%
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# (8, 4)
# 8
# 4

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Study Hours  8 non-null      int64
#  1   Attendance   8 non-null      int64
#  2   Gender       8 non-null      str
#  3   Result       8 non-null      str
# dtypes: int64(2), str(2)
# memory usage: 388.0 bytes

# %%
df.describe()
df.describe()["Study Hours"]["25%"]
df.describe()["Study Hours"]["75%"]
# Out:
# np.float64(6.25)

# %%
categorical_col = df.select_dtypes(include=["str"]).columns
print (categorical_col)
numerical_col = df.select_dtypes(include= ["int64","float64"]).columns
print(numerical_col)
# Out:
# Index(['Gender', 'Result'], dtype='str')
# Index(['Study Hours', 'Attendance'], dtype='str')

# %%
import pandas as pd

df = pd.DataFrame({
    "Age": ["20", "21", "22", "23"],
    "Height": ["5.5", "5.7", "5.9", "6.0"],
    "id": [101, 102, 103, 104],
    "Marks": ["80", "90", "abc", "70"]
})

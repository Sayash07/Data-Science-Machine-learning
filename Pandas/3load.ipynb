# %%
import pandas as pd


df = pd.read_csv("Students.csv")
#df = pd.read_excel("Students.xlsx")
#df = pd.read_json("Students.json")

df
# Out:
#     name  age  gender
# 0  nitan   20    Male
# 1   Hari   21    Male
# 2  Shyam   24    Male
# 3   Sita   28  Female

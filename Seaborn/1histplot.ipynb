# %%
#Histplot
#It is a count plot of range input


python_marks=[31,23,56,75,43,67,45,89]

# %%
#plot:
# Single Variable plot
    #Histplot (Range of data )
    #countplot(Categorical data)

#2 variable plot
    #barplot categorical Vs N
    #scatterplot  Numerical vs Numerical

# %%
from matplotlib import pyplot as plt
import seaborn as sns
sns.histplot(x= python_marks , bins=[20,40,60,80,100])
plt.show()

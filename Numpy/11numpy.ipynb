# %% [markdown]
# +,-,*,/

# %%
import numpy as np


ar1 = np.array([1,2,3])
ar2 = np.array([1,3,4])
print(ar1 +ar2)
print(ar1*ar2)
# Out:
# [2 5 7]
# [ 1  6 12]

# %%
#For 2D array
ar2 = np.array([1,2],[3,4])
ar3 = np.array([1,1],[0,0])

ar2 + ar3

""" 
1 2     1 1     2 3
3 4     0 0     3 4

"""

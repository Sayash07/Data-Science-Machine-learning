# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Ram", "Shyam", "Ram", "Hari"],
    "Age": [20, 21, 20, 22]
})

print(df)
# Out:
#     Name  Age
# 0    Ram   20
# 1  Shyam   21
# 2    Ram   20
# 3   Hari   22

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#     Name  Age
# 0    Ram   20
# 1  Shyam   21
# 3   Hari   22

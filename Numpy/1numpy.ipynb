# %%
import numpy as np 
l1 = np.array([1,2,3,4,5,6])
print(l1)
print(l1[-1])
print(l1[2])
print(l1[0])
# Out:
# [1 2 3 4 5 6]
# 6
# 3
# 1

# %%
# Difference between list and numpy array
#List can hold all types of data
# Numpy array can hold only one data type
#If you put dufferent data then it converts all to string data type
a1 = [1,"Nitan", False]
print(a1)
a2 = np.array([1,"Nitan", False])
print(a2)
# Out:
# [1, 'Nitan', False]
# ['1' 'Nitan' 'False']

# %%
#Elements of numoy array should be of same length.
a3 = np.array([[1,2],[2,3],[3,4]])
print(a3)

#a4 = np.array([[1],[1,2],[1]])# It throws an error
#print(a4)
# Out:
# [[1 2]
#  [2 3]
#  [3 4]]

# %%
#We pass input and output to the model
#Model find equation based on inout and output 


#Introduction to Machine Learning
# Data >> We split data into training and testing data >>Training data is given to model (Incld both Input and Output)
# Model will give pattern(equation)
#we will give only input column to model for testing
# We re-check the testing data with equation and tally with our orginal data 



import pandas as pd

df = pd.DataFrame({
    "x": [-3, -2, -1, 0, 1, 2, 3, 4, 5],
    "y": [-6, -4, -2, 0, 2, 4, 6, 8, 10],
})

print(df)
# Out:
#    x   y
# 0 -3  -6
# 1 -2  -4
# 2 -1  -2
# 3  0   0
# 4  1   2
# 5  2   4
# 6  3   6
# 7  4   8
# 8  5  10

# %%
#Split train/test data:
from sklearn.model_selection import train_test_split

#X_train,X_test,Y_train,Y_test:
X = df.drop(columns="y")
y = df["y"]

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)
print(X_train)
print(y_train)


print(X_train)
print(y_test)
# Out:
#    x
# 0 -3
# 3  0
# 5  2
# 8  5
# 2 -1
# 7  4
# 1 -2
# 0    -6
# 3     0
# 5     4
# 8    10
# 2    -2
# 7     8
# 1    -4
# Name: y, dtype: int64
#    x
# 0 -3
# 3  0
# 5  2
# 8  5
# 2 -1
# 7  4
# 1 -2
# 4    2
# 6    6
# Name: y, dtype: int64

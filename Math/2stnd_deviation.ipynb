# %% [markdown]
# Standard Deviation:(Sigma)
# Standard deviation is a measure of how spread out the data is around its mean.
#
# 10,20,30,40,50
# mean = 30
# 20,10,0,-10,-20(Square all)/5 >> Variance
# Variance = 1000/5 = 200
# S.d = Root under (Variance) => 14.14

# %% [markdown]
# Z -score:( How many S.D is the data set away from mean)
#
# mean = 30
# z = (x-u)/S.d

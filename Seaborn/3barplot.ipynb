# %%
#it is ued to plot
#graph of categorical vs numerical data


import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "course": ["Python", "Java", "MERN"],
    "fee": [10000, 12000, 15000]
})

# %%
sns.barplot(x= df["course"], y=df["fee"])
plt.show()

# %%
import pandas as pd
import numpy as np
data = {
    "Name": ["Ram", "Sita", "Hari", "Gita", "Nabin", "Asha", "Rohan", "Mina", "Bikash", "Anita"],
    "Age": [20, 21, 19, 22, 20, 21, 23, 19, np.nan, 22],
    "Gender": ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F"],
    "City": ["Kathmandu", "Pokhara", "Kathmandu", "Lalitpur", "Kathmandu",
             "Pokhara", "Lalitpur", "Kathmandu", "Pokhara", "Kathmandu"],
    "Math": [80, 95, 75, np.nan, 85, 95, 60, 70, 88, 92],
    "Science": [75, 85, 80, 90, np.nan, 88, 65, 72, 82, 95],
    "English": [85, 88, 78, 92, 80, np.nan, 70, 75, 85, 90],
    "Attendance": [90, np.nan, 85, 92, np.nan, 98, np.nan, 80, np.nan, 96],
    "Grade": ["B", "A", "B", "A", "B", "A", "C", "C", "B", "A"]
}

df = pd.DataFrame(data)
df
# Out:
#      Name   Age Gender       City  Math  Science  English  Attendance Grade
# 0     Ram  20.0      M  Kathmandu  80.0     75.0     85.0        90.0     B
# 1    Sita  21.0      F    Pokhara  95.0     85.0     88.0         NaN     A
# 2    Hari  19.0      M  Kathmandu  75.0     80.0     78.0        85.0     B
# 3    Gita  22.0      F   Lalitpur   NaN     90.0     92.0        92.0     A
# 4   Nabin  20.0      M  Kathmandu  85.0      NaN     80.0         NaN     B
# 5    Asha  21.0      F    Pokhara  95.0     88.0      NaN        98.0     A
# 6   Rohan  23.0      M   Lalitpur  60.0     65.0     70.0         NaN     C
# 7    Mina  19.0      F  Kathmandu  70.0     72.0     75.0        80.0     C
# 8  Bikash   NaN      M    Pokhara  88.0     82.0     85.0         NaN     B
# 9   Anita  22.0      F  Kathmandu  92.0     95.0     90.0        96.0     A

# %%
#Find no of rows and colmns:
#display all columns names 
#check data types of all columns
#find the mean ,median,mode,of math marks
print(df.shape)
print(df.columns)
print(df.dtypes)
print(df["Math"].mean())
print(df["Math"].median())
print(df["Math"].mode())
# Out:
# (10, 9)
# Index(['Name', 'Age', 'Gender', 'City', 'Math', 'Science', 'English',
#        'Attendance', 'Grade'],
#       dtype='str')
# Name              str
# Age           float64
# Gender            str
# City              str
# Math          float64
# Science       float64
# English       float64
# Attendance    float64
# Grade             str
# dtype: object
# 82.22222222222223
# 85.0
# 0    95.0
# Name: Math, dtype: float64

# %%
#Pandas >> Manipulate Tablular Data (Data Frame)

import pandas as pd


Students = {
    "name" : ["nitan", "Hari", "Shyam", "Sita"],
    "age" : [20,21,24,28],
    "gender" : ["Male","Male", "Male", "Female"]
}

df = pd.DataFrame(Students)
print(df)
# Out:
#     name  age  gender
# 0  nitan   20    Male
# 1   Hari   21    Male
# 2  Shyam   24    Male
# 3   Sita   28  Female

# %% [markdown]
# Table >> DataFrame
# Column >> Series

# %%
df["age"][2] # Getting pirticular value from the data frame
